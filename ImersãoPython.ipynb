# %% [markdown]
# <a href="https://colab.research.google.com/github/joaospneto/imersaoalurapandas/blob/main/Imers%C3%A3oPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# IMPORTAÇÃO DE **DADOS**

# %%
df_principal = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Principal")

# %%
df_principal.head(11)
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5   PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6   PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7   VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8   MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9   ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
# 10  RDOR3 2024-01-26        27.56          1.43           3.41         -4.17
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...    Variação $.2  \
# 0           2.26         15.97      9.18      9.56  ...    108151480.40
# 1         -12.11         50.56      6.66      6.86  ...  -1043592200.00
# 2           7.64         77.55     40.81     42.34  ...   7087772680.00
# 3          -4.89         18.85     51.89     53.17  ...  -1859212322.00
# 4          -3.66         20.70     36.37     37.32  ...   -264598820.90
# 5          -0.78          8.08     44.25     45.69  ...   -287350761.30
# 6           7.30         95.01     38.91     40.09  ...  12414434171.00
# 7          -9.97        -23.49     67.50     69.81  ... -32301586276.00
# 8          -0.81         24.02     27.71     28.36  ...    -61810930.37
# 9          -3.36         34.25     32.35     32.91  ...  -5477394315.00
# 10         -4.17         -6.01     26.90     27.91  ...  -1401013341.00
#
#     Resultado.2  Variação Ano %  Valor Inicial (R$).3    Variação $.3  \
# 0         Subiu            0.02                  9.29    108151480.40
# 1        Desceu           -0.12                  7.76  -1043592200.00
# 2         Subiu            0.08                 38.98   7087772680.00
# 3        Desceu           -0.05                 55.63  -1859212322.00
# 4        Desceu           -0.04                 38.51   -264598820.90
# 5        Desceu           -0.01                 46.05   -287350761.30
# 6         Subiu            0.07                 37.24  12414434171.00
# 7        Desceu           -0.10                 77.20 -32301586276.00
# 8        Desceu           -0.01                 28.42    -61810930.37
# 9        Desceu           -0.03                 33.95  -5477394315.00
# 10       Desceu           -0.04                 28.76  -1401013341.00
#
#    Resultado.3  Variação 12M %  Valor Inicial (R$).4    Variação $.4  \
# 0        Subiu            0.16                  8.19    673890100.70
# 1       Desceu            0.51                  4.53   2543452344.00
# 2        Subiu            0.78                 23.63  43616542549.00
# 3       Desceu            0.19                 44.52   5735330905.00
# 4       Desceu            0.21                 30.74   1194473548.00
# 5       Desceu            0.08                 42.27   2732643623.00
# 6        Subiu            0.95                 20.49  88902961362.00
# 7       Desceu           -0.23                 90.84 -89553127391.00
# 8       Desceu            0.24                 22.73   1465984667.00
# 9       Desceu            0.34                 24.44  40191843998.00
# 10      Desceu           -0.06                 29.32  -2058735372.00
#
#    Resultado.4
# 0        Subiu
# 1        Subiu
# 2        Subiu
# 3        Subiu
# 4        Subiu
# 5        Subiu
# 6        Subiu
# 7       Desceu
# 8        Subiu
# 9        Subiu
# 10      Desceu
#
# [11 rows x 32 columns]

# %%
df_total_acoes = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes.head(11)
# Out:
#    Código  Qtde. Teórica
# 0   RRRP3   235665566.00
# 1   ALOS3   532616595.00
# 2   ALPA4   176733968.00
# 3   ABEV3  4394245879.00
# 4   ARZZ3    62305891.00
# 5   ASAI3  1349217892.00
# 6   AZUL4   327593725.00
# 7   B3SA3  5602790110.00
# 8   BBSE3   671750768.00
# 9   BBDC3  1500728902.00
# 10  BBDC4  5146576868.00

# %%
df_Ticker = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Ticker")
df_Ticker.head(11)
# Out:
#    Ticker            Nome
# 0   MGLU3  Magazine Luiza
# 1   HAPV3         Hapvida
# 2   PETR4       Petrobras
# 3   B3SA3              B3
# 4   USIM5        Usiminas
# 5   CVCB3             CVC
# 6   CIEL3           Cielo
# 7   VALE3            Vale
# 8   GOLL4             GOL
# 9   BBDC4  Banco Bradesco
# 10  AZUL4            Azul

# %%
df_Ticker = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Ticker")
df_Ticker.head(11)
# Out:
#    Ticker            Nome
# 0   MGLU3  Magazine Luiza
# 1   HAPV3         Hapvida
# 2   PETR4       Petrobras
# 3   B3SA3              B3
# 4   USIM5        Usiminas
# 5   CVCB3             CVC
# 6   CIEL3           Cielo
# 7   VALE3            Vale
# 8   GOLL4             GOL
# 9   BBDC4  Banco Bradesco
# 10  AZUL4            Azul

# %%
df_Chatgpt = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Chatgpt")
df_Chatgpt.head(11)
# Out:
#    Nome da empresa          Segmento  Idade (anos)
# 0         Usiminas        Siderurgia            60
# 1    CSN Mineração         Mineração             8
# 2        Petrobras          Petróleo            69
# 3           Suzano  Papel e Celulose            94
# 4     CPFL Energia           Energia           109
# 5         PetroRio          Petróleo             9
# 6        Petrobras          Petróleo            69
# 7             Vale         Mineração            79
# 8        Multiplan  Shopping Centers            48
# 9    Itaú Unibanco             Banco            13
# 10       Rede D'Or             Saúde            48

# %%
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...   Variação $.2  \
# 0           2.26         15.97      9.18      9.56  ...   108151480.40
# 1         -12.11         50.56      6.66      6.86  ... -1043592200.00
# 2           7.64         77.55     40.81     42.34  ...  7087772680.00
# 3          -4.89         18.85     51.89     53.17  ... -1859212322.00
# 4          -3.66         20.70     36.37     37.32  ...  -264598820.90
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...  -929460216.60
# 77        -23.55        -85.74      8.67      8.95  ...  -254178125.40
# 78        -11.57         -2.77     56.04     58.90  ... -6278141320.00
# 79        -12.29        -36.83      3.05      3.23  ...  -226090475.70
# 80        -34.00        -25.44      5.51      6.02  ...  -604403916.40
#
#     Resultado.2  Variação Ano %  Valor Inicial (R$).3   Variação $.3  \
# 0         Subiu            0.02                  9.29   108151480.40
# 1        Desceu           -0.12                  7.76 -1043592200.00
# 2         Subiu            0.08                 38.98  7087772680.00
# 3        Desceu           -0.05                 55.63 -1859212322.00
# 4        Desceu           -0.04                 38.51  -264598820.90
# ..          ...             ...                   ...            ...
# 76       Desceu           -0.14                 12.45  -929460216.60
# 77       Desceu           -0.24                 11.38  -254178125.40
# 78       Desceu           -0.12                 63.60 -6278141320.00
# 79       Desceu           -0.12                  3.50  -226090475.70
# 80       Desceu           -0.34                  8.97  -604403916.40
#
#    Resultado.3  Variação 12M %  Valor Inicial (R$).4   Variação $.4  \
# 0        Subiu            0.16                  8.19   673890100.70
# 1       Desceu            0.51                  4.53  2543452344.00
# 2        Subiu            0.78                 23.63 43616542549.00
# 3       Desceu            0.19                 44.52  5735330905.00
# 4       Desceu            0.21                 30.74  1194473548.00
# ..         ...             ...                   ...            ...
# 76      Desceu           -0.33                 15.92 -2781316323.00
# 77      Desceu           -0.86                 61.01 -4961222496.00
# 78      Desceu           -0.03                 57.84 -1367026195.00
# 79      Desceu           -0.37                  4.86  -940741575.30
# 80      Desceu           -0.25                  7.94  -400316504.60
#
#    Resultado.4
# 0        Subiu
# 1        Subiu
# 2        Subiu
# 3        Subiu
# 4        Subiu
# ..         ...
# 76      Desceu
# 77      Desceu
# 78      Desceu
# 79      Desceu
# 80      Desceu
#
# [81 rows x 32 columns]

# %%
df_principal = df_principal.rename(columns={"Último (R$)": "valor_final","Var. Dia (%)": "var_dia_pct"}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...   Variação $.3  \
# 0           2.26         15.97      9.18      9.56  ...   108151480.40
# 1         -12.11         50.56      6.66      6.86  ... -1043592200.00
# 2           7.64         77.55     40.81     42.34  ...  7087772680.00
# 3          -4.89         18.85     51.89     53.17  ... -1859212322.00
# 4          -3.66         20.70     36.37     37.32  ...  -264598820.90
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...  -929460216.60
# 77        -23.55        -85.74      8.67      8.95  ...  -254178125.40
# 78        -11.57         -2.77     56.04     58.90  ... -6278141320.00
# 79        -12.29        -36.83      3.05      3.23  ...  -226090475.70
# 80        -34.00        -25.44      5.51      6.02  ...  -604403916.40
#
#     Resultado.3  Variação 12M %  Valor Inicial (R$).4   Variação $.4  \
# 0         Subiu            0.16                  8.19   673890100.70
# 1        Desceu            0.51                  4.53  2543452344.00
# 2         Subiu            0.78                 23.63 43616542549.00
# 3        Desceu            0.19                 44.52  5735330905.00
# 4        Desceu            0.21                 30.74  1194473548.00
# ..          ...             ...                   ...            ...
# 76       Desceu           -0.33                 15.92 -2781316323.00
# 77       Desceu           -0.86                 61.01 -4961222496.00
# 78       Desceu           -0.03                 57.84 -1367026195.00
# 79       Desceu           -0.37                  4.86  -940741575.30
# 80       Desceu           -0.25                  7.94  -400316504.60
#
#    Resultado.4  var_pct  valor_inicial  Código Qtde. Teórica
# 0        Subiu     0.05           9.03   USIM5  515117391.00
# 1        Subiu     0.02           6.66   CMIN3 1110559345.00
# 2        Subiu     0.02          41.06   PETR3 2379877655.00
# 3        Subiu     0.02          51.85   SUZB3  683452836.00
# 4        Subiu     0.02          36.36   CPFE3  187732538.00
# ..         ...      ...            ...     ...           ...
# 76      Desceu    -0.02          10.98   CRFB3  533990587.00
# 77      Desceu    -0.02           8.92   BHIA3   94843047.00
# 78      Desceu    -0.04          58.36   RENT3  853202347.00
# 79      Desceu    -0.04           3.21   CVCB3  525582771.00
# 80      Desceu    -0.08           6.44   GOLL4  198184909.00
#
# [81 rows x 36 columns]

# %%
df_principal["var_pct"] = df_principal["var_dia_pct"] / 100
df_principal["valor_inicial"] = df_principal["valor_final"] / (df_principal["var_pct"] +1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variação Ano %  \
# 0           2.26         15.97      9.18      9.56  ...           0.02
# 1         -12.11         50.56      6.66      6.86  ...          -0.12
# 2           7.64         77.55     40.81     42.34  ...           0.08
# 3          -4.89         18.85     51.89     53.17  ...          -0.05
# 4          -3.66         20.70     36.37     37.32  ...          -0.04
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...          -0.14
# 77        -23.55        -85.74      8.67      8.95  ...          -0.24
# 78        -11.57         -2.77     56.04     58.90  ...          -0.12
# 79        -12.29        -36.83      3.05      3.23  ...          -0.12
# 80        -34.00        -25.44      5.51      6.02  ...          -0.34
#
#     Valor Inicial (R$).3   Variação $.3  Resultado.3  Variação 12M %  \
# 0                   9.29   108151480.40        Subiu            0.16
# 1                   7.76 -1043592200.00       Desceu            0.51
# 2                  38.98  7087772680.00        Subiu            0.78
# 3                  55.63 -1859212322.00       Desceu            0.19
# 4                  38.51  -264598820.90       Desceu            0.21
# ..                   ...            ...          ...             ...
# 76                 12.45  -929460216.60       Desceu           -0.33
# 77                 11.38  -254178125.40       Desceu           -0.86
# 78                 63.60 -6278141320.00       Desceu           -0.03
# 79                  3.50  -226090475.70       Desceu           -0.37
# 80                  8.97  -604403916.40       Desceu           -0.25
#
#    Valor Inicial (R$).4   Variação $.4  Resultado.4  var_pct valor_inicial
# 0                  8.19   673890100.70        Subiu     0.05          9.03
# 1                  4.53  2543452344.00        Subiu     0.02          6.66
# 2                 23.63 43616542549.00        Subiu     0.02         41.06
# 3                 44.52  5735330905.00        Subiu     0.02         51.85
# 4                 30.74  1194473548.00        Subiu     0.02         36.36
# ..                  ...            ...          ...      ...           ...
# 76                15.92 -2781316323.00       Desceu    -0.02         10.98
# 77                61.01 -4961222496.00       Desceu    -0.02          8.92
# 78                57.84 -1367026195.00       Desceu    -0.04         58.36
# 79                 4.86  -940741575.30       Desceu    -0.04          3.21
# 80                 7.94  -400316504.60       Desceu    -0.08          6.44
#
# [81 rows x 34 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...   Variação $.3  \
# 0           2.26         15.97      9.18      9.56  ...   108151480.40
# 1         -12.11         50.56      6.66      6.86  ... -1043592200.00
# 2           7.64         77.55     40.81     42.34  ...  7087772680.00
# 3          -4.89         18.85     51.89     53.17  ... -1859212322.00
# 4          -3.66         20.70     36.37     37.32  ...  -264598820.90
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...  -929460216.60
# 77        -23.55        -85.74      8.67      8.95  ...  -254178125.40
# 78        -11.57         -2.77     56.04     58.90  ... -6278141320.00
# 79        -12.29        -36.83      3.05      3.23  ...  -226090475.70
# 80        -34.00        -25.44      5.51      6.02  ...  -604403916.40
#
#     Resultado.3  Variação 12M %  Valor Inicial (R$).4   Variação $.4  \
# 0         Subiu            0.16                  8.19   673890100.70
# 1        Desceu            0.51                  4.53  2543452344.00
# 2         Subiu            0.78                 23.63 43616542549.00
# 3        Desceu            0.19                 44.52  5735330905.00
# 4        Desceu            0.21                 30.74  1194473548.00
# ..          ...             ...                   ...            ...
# 76       Desceu           -0.33                 15.92 -2781316323.00
# 77       Desceu           -0.86                 61.01 -4961222496.00
# 78       Desceu           -0.03                 57.84 -1367026195.00
# 79       Desceu           -0.37                  4.86  -940741575.30
# 80       Desceu           -0.25                  7.94  -400316504.60
#
#    Resultado.4  var_pct  valor_inicial  Código Qtde. Teórica
# 0        Subiu     0.05           9.03   USIM5  515117391.00
# 1        Subiu     0.02           6.66   CMIN3 1110559345.00
# 2        Subiu     0.02          41.06   PETR3 2379877655.00
# 3        Subiu     0.02          51.85   SUZB3  683452836.00
# 4        Subiu     0.02          36.36   CPFE3  187732538.00
# ..         ...      ...            ...     ...           ...
# 76      Desceu    -0.02          10.98   CRFB3  533990587.00
# 77      Desceu    -0.02           8.92   BHIA3   94843047.00
# 78      Desceu    -0.04          58.36   RENT3  853202347.00
# 79      Desceu    -0.04           3.21   CVCB3  525582771.00
# 80      Desceu    -0.08           6.44   GOLL4  198184909.00
#
# [81 rows x 36 columns]

# %%
df_principal = df_principal.rename(columns={"Qtde. Teórica_y": "Qtde.Teórica"}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...   Variação $.3  \
# 0           2.26         15.97      9.18      9.56  ...   108151480.40
# 1         -12.11         50.56      6.66      6.86  ... -1043592200.00
# 2           7.64         77.55     40.81     42.34  ...  7087772680.00
# 3          -4.89         18.85     51.89     53.17  ... -1859212322.00
# 4          -3.66         20.70     36.37     37.32  ...  -264598820.90
# ..           ...           ...       ...       ...  ...            ...
# 76        -13.98        -32.72     10.70     11.08  ...  -929460216.60
# 77        -23.55        -85.74      8.67      8.95  ...  -254178125.40
# 78        -11.57         -2.77     56.04     58.90  ... -6278141320.00
# 79        -12.29        -36.83      3.05      3.23  ...  -226090475.70
# 80        -34.00        -25.44      5.51      6.02  ...  -604403916.40
#
#     Resultado.3  Variação 12M %  Valor Inicial (R$).4   Variação $.4  \
# 0         Subiu            0.16                  8.19   673890100.70
# 1        Desceu            0.51                  4.53  2543452344.00
# 2         Subiu            0.78                 23.63 43616542549.00
# 3        Desceu            0.19                 44.52  5735330905.00
# 4        Desceu            0.21                 30.74  1194473548.00
# ..          ...             ...                   ...            ...
# 76       Desceu           -0.33                 15.92 -2781316323.00
# 77       Desceu           -0.86                 61.01 -4961222496.00
# 78       Desceu           -0.03                 57.84 -1367026195.00
# 79       Desceu           -0.37                  4.86  -940741575.30
# 80       Desceu           -0.25                  7.94  -400316504.60
#
#    Resultado.4  var_pct  valor_inicial  Código Qtde. Teórica
# 0        Subiu     0.05           9.03   USIM5  515117391.00
# 1        Subiu     0.02           6.66   CMIN3 1110559345.00
# 2        Subiu     0.02          41.06   PETR3 2379877655.00
# 3        Subiu     0.02          51.85   SUZB3  683452836.00
# 4        Subiu     0.02          36.36   CPFE3  187732538.00
# ..         ...      ...            ...     ...           ...
# 76      Desceu    -0.02          10.98   CRFB3  533990587.00
# 77      Desceu    -0.02           8.92   BHIA3   94843047.00
# 78      Desceu    -0.04          58.36   RENT3  853202347.00
# 79      Desceu    -0.04           3.21   CVCB3  525582771.00
# 80      Desceu    -0.08           6.44   GOLL4  198184909.00
#
# [81 rows x 36 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50         5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82         2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96         2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91         2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10         2.03           2.49         -3.66
# ..    ...        ...          ...          ...            ...           ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24        -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07        -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92        -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Resultado.3  \
# 0           2.26         15.97      9.18      9.56  ...       Subiu
# 1         -12.11         50.56      6.66      6.86  ...      Desceu
# 2           7.64         77.55     40.81     42.34  ...       Subiu
# 3          -4.89         18.85     51.89     53.17  ...      Desceu
# 4          -3.66         20.70     36.37     37.32  ...      Desceu
# ..           ...           ...       ...       ...  ...         ...
# 76        -13.98        -32.72     10.70     11.08  ...      Desceu
# 77        -23.55        -85.74      8.67      8.95  ...      Desceu
# 78        -11.57         -2.77     56.04     58.90  ...      Desceu
# 79        -12.29        -36.83      3.05      3.23  ...      Desceu
# 80        -34.00        -25.44      5.51      6.02  ...      Desceu
#
#     Variação 12M %  Valor Inicial (R$).4   Variação $.4  Resultado.4 var_pct  \
# 0             0.16                  8.19   673890100.70        Subiu    0.05
# 1             0.51                  4.53  2543452344.00        Subiu    0.02
# 2             0.78                 23.63 43616542549.00        Subiu    0.02
# 3             0.19                 44.52  5735330905.00        Subiu    0.02
# 4             0.21                 30.74  1194473548.00        Subiu    0.02
# ..             ...                   ...            ...          ...     ...
# 76           -0.33                 15.92 -2781316323.00       Desceu   -0.02
# 77           -0.86                 61.01 -4961222496.00       Desceu   -0.02
# 78           -0.03                 57.84 -1367026195.00       Desceu   -0.04
# 79           -0.37                  4.86  -940741575.30       Desceu   -0.04
# 80           -0.25                  7.94  -400316504.60       Desceu   -0.08
#
#     valor_inicial  Código  Qtde. Teórica    Variacao_rs
# 0            9.03   USIM5   515117391.00   241889725.43
# 1            6.66   CMIN3  1110559345.00   177515970.30
# 2           41.06   PETR3  2379877655.00  2140059393.53
# 3           51.85   SUZB3   683452836.00   722946282.71
# 4           36.36   CPFE3   187732538.00   138573955.06
# ..            ...     ...            ...            ...
# 76          10.98   CRFB3   533990587.00  -143635530.57
# 77           8.92   BHIA3    94843047.00   -20810240.84
# 78          58.36   RENT3   853202347.00 -1807432634.46
# 79           3.21   CVCB3   525582771.00   -73557408.06
# 80           6.44   GOLL4   198184909.00  -102993202.62
#
# [81 rows x 37 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'var_dia_pct', 'var_pct', 'valor_inicial','Qtde. Teórica', 'Variacao_rs' ]].copy()
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03   515117391.00
# 1   CMIN3 2024-01-26         2.40     0.02           6.66  1110559345.00
# 2   PETR3 2024-01-26         2.19     0.02          41.06  2379877655.00
# 3   SUZB3 2024-01-26         2.04     0.02          51.85   683452836.00
# 4   CPFE3 2024-01-26         2.03     0.02          36.36   187732538.00
# ..    ...        ...          ...      ...            ...            ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98   533990587.00
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92    94843047.00
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36   853202347.00
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21   525582771.00
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44   198184909.00
#
#       Variacao_rs
# 0    241889725.43
# 1    177515970.30
# 2   2140059393.53
# 3    722946282.71
# 4    138573955.06
# ..            ...
# 76  -143635530.57
# 77   -20810240.84
# 78 -1807432634.46
# 79   -73557408.06
# 80  -102993202.62
#
# [81 rows x 7 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format


df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03   515117391.00
# 1   CMIN3 2024-01-26         2.40     0.02           6.66  1110559345.00
# 2   PETR3 2024-01-26         2.19     0.02          41.06  2379877655.00
# 3   SUZB3 2024-01-26         2.04     0.02          51.85   683452836.00
# 4   CPFE3 2024-01-26         2.03     0.02          36.36   187732538.00
# ..    ...        ...          ...      ...            ...            ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98   533990587.00
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92    94843047.00
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36   853202347.00
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21   525582771.00
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44   198184909.00
#
#       Variacao_rs
# 0    241889725.43
# 1    177515970.30
# 2   2140059393.53
# 3    722946282.71
# 4    138573955.06
# ..            ...
# 76  -143635530.57
# 77   -20810240.84
# 78 -1807432634.46
# 79   -73557408.06
# 80  -102993202.62
#
# [81 rows x 7 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03      515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66     1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06     2379877655
# 3   SUZB3 2024-01-26         2.04     0.02          51.85      683452836
# 4   CPFE3 2024-01-26         2.03     0.02          36.36      187732538
# ..    ...        ...          ...      ...            ...            ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98      533990587
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92       94843047
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36      853202347
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21      525582771
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44      198184909
#
#       Variacao_rs
# 0    241889725.43
# 1    177515970.30
# 2   2140059393.53
# 3    722946282.71
# 4    138573955.06
# ..            ...
# 76  -143635530.57
# 77   -20810240.84
# 78 -1807432634.46
# 79   -73557408.06
# 80  -102993202.62
#
# [81 rows x 7 columns]

# %%
df_principal = df_principal.rename(columns={"Qtde. Teórica": "qtd_teorica"}).copy()
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  qtd_teorica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03    515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66   1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 3   SUZB3 2024-01-26         2.04     0.02          51.85    683452836
# 4   CPFE3 2024-01-26         2.03     0.02          36.36    187732538
# ..    ...        ...          ...      ...            ...          ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98    533990587
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92     94843047
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36    853202347
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21    525582771
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44    198184909
#
#       Variacao_rs
# 0    241889725.43
# 1    177515970.30
# 2   2140059393.53
# 3    722946282.71
# 4    138573955.06
# ..            ...
# 76  -143635530.57
# 77   -20810240.84
# 78 -1807432634.46
# 79   -73557408.06
# 80  -102993202.62
#
# [81 rows x 7 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else 'Desceu' if x < 0 else 'Estável')
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  qtd_teorica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03    515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66   1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 3   SUZB3 2024-01-26         2.04     0.02          51.85    683452836
# 4   CPFE3 2024-01-26         2.03     0.02          36.36    187732538
# ..    ...        ...          ...      ...            ...          ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98    533990587
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92     94843047
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36    853202347
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21    525582771
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44    198184909
#
#       Variacao_rs Resultado
# 0    241889725.43     Subiu
# 1    177515970.30     Subiu
# 2   2140059393.53     Subiu
# 3    722946282.71     Subiu
# 4    138573955.06     Subiu
# ..            ...       ...
# 76  -143635530.57    Desceu
# 77   -20810240.84    Desceu
# 78 -1807432634.46    Desceu
# 79   -73557408.06    Desceu
# 80  -102993202.62    Desceu
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  qtd_teorica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03    515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66   1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 3   SUZB3 2024-01-26         2.04     0.02          51.85    683452836
# 4   CPFE3 2024-01-26         2.03     0.02          36.36    187732538
# ..    ...        ...          ...      ...            ...          ...
# 76  CRFB3 2024-01-26        -2.45    -0.02          10.98    533990587
# 77  BHIA3 2024-01-26        -2.46    -0.02           8.92     94843047
# 78  RENT3 2024-01-26        -3.63    -0.04          58.36    853202347
# 79  CVCB3 2024-01-26        -4.36    -0.04           3.21    525582771
# 80  GOLL4 2024-01-26        -8.07    -0.08           6.44    198184909
#
#       Variacao_rs Resultado              Nome
# 0    241889725.43     Subiu          Usiminas
# 1    177515970.30     Subiu     CSN Mineração
# 2   2140059393.53     Subiu         Petrobras
# 3    722946282.71     Subiu            Suzano
# 4    138573955.06     Subiu      CPFL Energia
# ..            ...       ...               ...
# 76  -143635530.57    Desceu  Carrefour Brasil
# 77   -20810240.84    Desceu       Casas Bahia
# 78 -1807432634.46    Desceu          Localiza
# 79   -73557408.06    Desceu               CVC
# 80  -102993202.62    Desceu               GOL
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_Chatgpt, left_on='Nome', right_on='Nome da empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da empresa'])
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  qtd_teorica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03    515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66   1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 3   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 4   SUZB3 2024-01-26         2.04     0.02          51.85    683452836
# ..    ...        ...          ...      ...            ...          ...
# 82  CRFB3 2024-01-26        -2.45    -0.02          10.98    533990587
# 83  BHIA3 2024-01-26        -2.46    -0.02           8.92     94843047
# 84  RENT3 2024-01-26        -3.63    -0.04          58.36    853202347
# 85  CVCB3 2024-01-26        -4.36    -0.04           3.21    525582771
# 86  GOLL4 2024-01-26        -8.07    -0.08           6.44    198184909
#
#       Variacao_rs Resultado              Nome           Segmento  Idade (anos)
# 0    241889725.43     Subiu          Usiminas         Siderurgia            60
# 1    177515970.30     Subiu     CSN Mineração          Mineração             8
# 2   2140059393.53     Subiu         Petrobras           Petróleo            69
# 3   2140059393.53     Subiu         Petrobras           Petróleo            69
# 4    722946282.71     Subiu            Suzano   Papel e Celulose            94
# ..            ...       ...               ...                ...           ...
# 82  -143635530.57    Desceu  Carrefour Brasil             Varejo            37
# 83   -20810240.84    Desceu       Casas Bahia             Varejo            95
# 84 -1807432634.46    Desceu          Localiza  Aluguel de Carros            49
# 85   -73557408.06    Desceu               CVC            Turismo            50
# 86  -102993202.62    Desceu               GOL            Aviação            20
#
# [87 rows x 11 columns]

# %%
df_Chatgpt
# Out:
#      Nome da empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração             8
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            94
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            37
# 77       Casas Bahia             Varejo            95
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            50
# 80               GOL            Aviação            20
#
# [81 rows x 3 columns]

# %%
df_principal = df_principal.rename(columns={"Idade (anos)": "Ano_de_fundacao"}).copy()
df_principal
# Out:
#     Ativo       Data  var_dia_pct  var_pct  valor_inicial  qtd_teorica  \
# 0   USIM5 2024-01-26         5.20     0.05           9.03    515117391
# 1   CMIN3 2024-01-26         2.40     0.02           6.66   1110559345
# 2   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 3   PETR3 2024-01-26         2.19     0.02          41.06   2379877655
# 4   SUZB3 2024-01-26         2.04     0.02          51.85    683452836
# ..    ...        ...          ...      ...            ...          ...
# 82  CRFB3 2024-01-26        -2.45    -0.02          10.98    533990587
# 83  BHIA3 2024-01-26        -2.46    -0.02           8.92     94843047
# 84  RENT3 2024-01-26        -3.63    -0.04          58.36    853202347
# 85  CVCB3 2024-01-26        -4.36    -0.04           3.21    525582771
# 86  GOLL4 2024-01-26        -8.07    -0.08           6.44    198184909
#
#       Variacao_rs Resultado              Nome           Segmento  \
# 0    241889725.43     Subiu          Usiminas         Siderurgia
# 1    177515970.30     Subiu     CSN Mineração          Mineração
# 2   2140059393.53     Subiu         Petrobras           Petróleo
# 3   2140059393.53     Subiu         Petrobras           Petróleo
# 4    722946282.71     Subiu            Suzano   Papel e Celulose
# ..            ...       ...               ...                ...
# 82  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 83   -20810240.84    Desceu       Casas Bahia             Varejo
# 84 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 85   -73557408.06    Desceu               CVC            Turismo
# 86  -102993202.62    Desceu               GOL            Aviação
#
#     Ano_de_fundacao
# 0                60
# 1                 8
# 2                69
# 3                69
# 4                94
# ..              ...
# 82               37
# 83               95
# 84               49
# 85               50
# 86               20
#
# [87 rows x 11 columns]

# %%
data = {'Variacao_rs': [1000000, - 500000, 200000, -750000, 3000000],
        'Resultado': ['Subiu', 'Desceu', 'Subiu', 'Desceu', 'Subiu']}
df_principal = pd.DataFrame(data)

# Calcular estatísticas
maior = df_principal['Variacao_rs'].max()
menor = df_principal['Variacao_rs'].min()
media = df_principal['Variacao_rs'].mean()
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimir os resultados
print(f"Maior R$ {maior:,.2f}")
print(f"Menor -R$ {abs(menor):,.2f}")
print(f"Média R$ {media:,.2f}")
print(f"Média de quem subiu R$ {media_subiu:,.2f}")
print(f"Média de quem desceu -R$ {abs(media_desceu):,.2f}")
# Out:
# Maior R$ 3,000,000.00
# Menor -R$ 750,000.00
# Média R$ 590,000.00
# Média de quem subiu R$ 1,400,000.00
# Média de quem desceu -R$ 625,000.00

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#    Variacao_rs Resultado
# 0      1000000     Subiu
# 2       200000     Subiu
# 4      3000000     Subiu

# %%
df_analise_segmento = df_principal_subiu.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#   Resultado  Variacao_rs
# 0     Subiu      4200000

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado  Variacao_rs
# 0    Desceu     -1250000
# 1     Subiu      4200000

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b090467c-7f97-4ca7-8f6f-8bb9777841b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b090467c-7f97-4ca7-8f6f-8bb9777841b1")) {                    Plotly.newPlot(                        "b090467c-7f97-4ca7-8f6f-8bb9777841b1",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-1250000.0,4200000.0],"textposition":"auto","x":["Desceu","Subiu"],"xaxis":"x","y":[-1250000,4200000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar": ...
